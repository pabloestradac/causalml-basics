# %% [markdown]
# # Wage Prediction using Machine Learning
#
# In this notebook we will answer what determines the wage of workers from a predictive perspective.
#
# This example focuses on a sample of Registered Nurses in the US collected during 2017. The hourly wage of a nurse is denoted by $Y$ and $X$ is a vector of nurses' characteristics, e.g., human capital, demographics, job-relevant characteristics. The question that we want to answer is:
#
# - How to use nurses' characteristics, such as education and experience, to best predict wages?

# %%
import numpy as np
import pandas as pd
import patsy
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LassoCV, RidgeCV, ElasticNetCV, LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, StackingRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.base import TransformerMixin, RegressorMixin, BaseEstimator
from sklearn.pipeline import make_pipeline

import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# ## Data

# %%
# Read data
df = pd.read_csv('data/wages_nurses.csv')
df.tail()
# Out:
#          lwage  female  age   race  children               marital education  \
# 5617  3.496087       1   72  white         0  widowed_divorced_sep  ed_assoc
# 5618  3.678408       1   50  white         0         never_married    ed_msn
# 5619  3.952845       0   36  white         0     currently_married    ed_bsn
# 5620  3.957960       1   61  white         0     currently_married    ed_bsn
# 5621  3.100270       1   38  white         0     currently_married  ed_assoc
#
#       RN_experience left_nursing  country_ed_US  english_only  \
# 5617             51       left_0              1             1
# 5618             14       left_0              1             1
# 5619              4       left_0              1             1
# 5620             40       left_0              1             1
# 5621              3       left_0              1             1
#
#               military  certificates  labor_union             work_setting  \
# 5617  never_served_mil             0            0  SET_long_term_inpatient
# 5618  never_served_mil             0            0             SET_hospital
# 5619  never_served_mil             2            1             SET_hospital
# 5620  never_served_mil             0            0             SET_hospital
# 5621  never_served_mil             2            0             SET_hospital
#
#            work_situation       level_care       care_specialty      state
# 5617    SIT_self_employed  LC_nursing_home   CC_no_patient_care  state_n13
# 5618  SIT_agency_facility     LC_education    CC_emergency_care  state_n24
# 5619  SIT_agency_facility     LC_inpatient          CC_oncology  state_n32
# 5620  SIT_agency_facility     LC_inpatient   CC_no_patient_care  state_n37
# 5621  SIT_agency_facility        LC_others  CC_medical_surgical  state_n29

# %%
# Output variable
y = np.log(df['lwage']).values
Z = df.drop(['lwage'], axis=1)
Z.shape
# Out:
# (5622, 18)

# %% [markdown]
# Construct a prediction rule for hourly (log) wage $y$, which depends linearly on relevant characteristics $Z$:
#
# $$
# y = g(Z) + e
# $$
#
# Then, assess the predictive performance of a given model using the (adjusted) sample MSE, the (adjusted) sample $R^2$ and the out-of-sample MSE and $R^2$. Thus, we measure the prediction quality of the models via data splitting.

# %%
train_idx, test_idx = train_test_split(np.arange(len(y)), test_size=0.20, random_state=42)
y_train, y_test = y[train_idx], y[test_idx]

# %% [markdown]
# ## Linear Models
#
# We employ two different specifications for prediction:
#
# 1. Basic Model: $X$ consists of a set of raw regressors
#
# 2. Flexible Model: $X$ consists of all raw regressors from the basic model plus a dictionary of transformations.

# %%
model_base = ('0 + female + age + race + children + marital '
              '+ education + RN_experience + RN_experience**2 + RN_experience**3 + RN_experience**4 '
              '+ left_nursing + country_ed_US + english_only + military + certificates'
              '+ labor_union + work_setting + work_situation + level_care + care_specialty + state')
Zbase = patsy.dmatrix(model_base, Z, return_type='dataframe').values
X_train, X_test = Zbase[train_idx], Zbase[test_idx]

# %%
def metrics(X_test, y_test, estimator):
    mse = np.mean((y_test - estimator.predict(X_test))**2)
    semse = np.std((y_test - estimator.predict(X_test))**2) / np.sqrt(len(y_test))
    r2 = 1 - mse / np.var(y_test)
    print(f'{mse:.4f}, {semse:.4f}, {r2:.4f}')
    return mse, semse, r2

results = {}

# %% [markdown]
# Let's start by running a simple OLS regression.

# %%
# Basic model
lr = LinearRegression().fit(X_train, y_train)
ypred_ols = lr.predict(X_test)
results['ols'] = metrics(X_test, y_test, lr)
# Out:
# 0.0086, 0.0007, 0.2342

# %%
cv = KFold(n_splits=5, shuffle=True, random_state=42)

# Lasso
lcv = make_pipeline(StandardScaler(), LassoCV(cv=cv, random_state=42)).fit(X_train, y_train)
ypred_lcv = lcv.predict(X_test)
results['lassocv'] = metrics(X_test, y_test, lcv)
# Out:
# 0.0087, 0.0007, 0.2328

# %%
# Ridge
rcv = make_pipeline(StandardScaler(), RidgeCV(cv=cv)).fit(X_train, y_train)
ypred_rcv = rcv.predict(X_test)
results['ridgecv'] = metrics(X_test, y_test, rcv)
# Out:
# 0.0086, 0.0007, 0.2343

# %%
# Elastic Net
ecv = make_pipeline(StandardScaler(), ElasticNetCV(cv=cv, random_state=42)).fit(X_train, y_train)
ypred_ecv = ecv.predict(X_test)
results['elanetcv'] = metrics(X_test, y_test, ecv)
# Out:
# 0.0087, 0.0007, 0.2330

# %% [markdown]
# Use theoretical-optimal $\lambda$ for lasso.
#
# This is a based on a Python implementation made by [Max Huppertz](https://maxhuppertz.github.io/code/). His library is this [repository](https://github.com/maxhuppertz/hdmpy).
#
# Run the following code to install the library:
#
# ```python
# !git clone https://github.com/maxhuppertz/hdmpy.git
# !pip install multiprocess
# ```

# %%
import hdmpy

# Wrap the package so that it has the familiar sklearn API
class RLasso(BaseEstimator, RegressorMixin):

    def __init__(self, *, post=True):
        self.post = post

    def fit(self, X, y):
        self.rlasso_ = hdmpy.rlasso(X, y, post=self.post)
        return self

    @property
    def coef_(self):
        return np.array(self.rlasso_.est['beta']).flatten()

    @property
    def intercept_(self):
        return np.array(self.rlasso_.est['intercept'])

    def predict(self, X):
        return X @ self.coef_ + self.intercept_

# %%
# Optimal lasso
lasso = make_pipeline(StandardScaler(), RLasso(post=False)).fit(X_train, y_train)
ypred_lasso = lasso.predict(X_test)
results['lasso'] = metrics(X_test, y_test, lasso)
# Out:
# 0.0090, 0.0007, 0.2019

# %%
# Optimal post-lasso
postlasso = make_pipeline(StandardScaler(), RLasso(post=True)).fit(X_train, y_train)
ypred_postlasso = postlasso.predict(X_test)
results['postlasso'] = metrics(X_test, y_test, postlasso)
# Out:
# 0.0091, 0.0007, 0.1977

# %% [markdown]
# ## Non-Linear Models

# %% [markdown]
# Apply regression trees, random forests, boosted trees and neural nets to estimate the regression function $g(Z)$.

# %%
dtr = DecisionTreeRegressor(ccp_alpha=0.001, min_samples_leaf=5, random_state=42).fit(X_train, y_train)
ypred_dtr = dtr.predict(X_test)
results['trees'] = metrics(X_test, y_test, dtr)
# Out:
# 0.0113, 0.0008, -0.0005

# %%
rf = RandomForestRegressor(n_estimators=2000, min_samples_leaf=5, random_state=42)
rf.fit(X_train, y_train)
ypred_rf = rf.predict(X_test)
results['randforest'] = metrics(X_test, y_test, rf)
# Out:
# 0.0089, 0.0007, 0.2126

# %%
gbf = GradientBoostingRegressor(n_estimators=1000, learning_rate=.01,
                                subsample=.5, max_depth=2, random_state=42)
gbf.fit(X_train, y_train)
ypred_gbf = gbf.predict(X_test)
results['gradboost'] = metrics(X_test, y_test, gbf)
# Out:
# 0.0088, 0.0007, 0.2162

# %%
nnet = MLPRegressor((200, 20,), 'relu',
                    learning_rate_init=0.01, batch_size=10, max_iter=10, random_state=42)
nnet.fit(X_train, y_train)
ypred_nnet = nnet.predict(X_test)
results['neuralnet'] = metrics(X_test, y_test, nnet)
# Out:
# 0.0089, 0.0007, 0.2143

# %%
import skorch
from torch import nn, optim

arch = nn.Sequential(nn.Linear(X_train.shape[1], 200), nn.ReLU(),
                     nn.Linear(200, 20), nn.ReLU(),
                     nn.Linear(20, 1))
nnet_early = skorch.NeuralNetRegressor(arch, lr=0.01, batch_size=10,
                                       max_epochs=100,
                                       optimizer=optim.Adam,
                                       callbacks=[skorch.callbacks.EarlyStopping()])
nnet_early.fit(X_train.astype(np.float32), y_train.reshape(-1, 1).astype(np.float32))
ypred_nnet_early = nnet_early.predict(X_test.astype(np.float32)).flatten()
results['neuralnet_early'] = metrics(X_test.astype(np.float32),
                                y_test.reshape(-1, 1).astype(np.float32), nnet_early)
# Out:
#   epoch    train_loss    valid_loss     dur
# -------  ------------  ------------  ------
#       1        0.0496        0.0161  0.2114
#       2        0.0146        0.0132  0.1843
#       3        0.0111        0.0114  0.1822
#       4        0.0100        0.0129  0.1814
#       5        0.0095        0.0099  0.1836
#       6        0.0088        0.0099  0.1820
#       7        0.0083        0.0097  0.1814
#       8        0.0081        0.0084  0.1814
#       9        0.0080        0.0079  0.1814
#      10        0.0079        0.0081  0.1829
#      11        0.0077        0.0084  0.1809
#      12        0.0078        0.0090  0.1816
#      13        0.0078        0.0098  0.1817
# Stopping since valid_loss has not improved in the last 5 epochs.
# 0.0102, 0.0007, 0.0951

# %%
df = pd.DataFrame(results).T
df.columns = ['MSE', 'S.E. MSE', 'Rsq']
df.sort_values('MSE', ascending=True)
# Out:
#                       MSE  S.E. MSE       Rsq
# ridgecv          0.008646  0.000701  0.234312
# ols              0.008647  0.000701  0.234199
# elanetcv         0.008661  0.000703  0.232957
# lassocv          0.008663  0.000704  0.232775
# gradboost        0.008850  0.000694  0.216247
# neuralnet        0.008872  0.000718  0.214316
# randforest       0.008891  0.000667  0.212566
# lasso            0.009012  0.000728  0.201858
# postlasso        0.009059  0.000723  0.197714
# neuralnet_early  0.010218  0.000749  0.095105
# trees            0.011298  0.000780 -0.000550

# %% [markdown]
# ## Stacking

# %% [markdown]
# In the final step, build a prediction model by combining the strength of each model.
# $$
# g(z) = \sum_{k=1}^K \alpha_k g_k(z)
# $$
# where $g_k$'s denote our prediction rules from the table above and the $\alpha_k$'s are the corresponding weights.

# %%
method_name = ['OLS', 'CV Lasso', 'CV Ridge', 'CV ElasticNet', 'Lasso', 'Post-Lasso OLS',
               'Decision Tree', 'Random Forest', 'Boosted Forest', 'Neural Net', 'Neural Net (early stopping)']
ypreds = np.stack((ypred_ols, ypred_lcv, ypred_rcv, ypred_ecv, ypred_lasso, ypred_postlasso,
                   ypred_dtr, ypred_rf, ypred_gbf, ypred_nnet, ypred_nnet_early), axis=-1)
stack_ols = LinearRegression().fit(ypreds, y_test)
pd.DataFrame({'weight': stack_ols.coef_}, index=method_name).round(2)
# Out:
#                              weight
# OLS                            2.77
# CV Lasso                     -21.29
# CV Ridge                      -2.56
# CV ElasticNet                 21.59
# Lasso                         -0.69
# Post-Lasso OLS                 0.38
# Decision Tree                  4.17
# Random Forest                  0.42
# Boosted Forest                 0.14
# Neural Net                     0.32
# Neural Net (early stopping)   -0.03

# %%
# Calculate the test sample MSE and Rsq
# We should have left out a third sample to validate the performance of the stacked model
mse = np.mean((y_test - stack_ols.predict(ypreds))**2)
r2 = 1 - mse / np.var(y_test)
print(f'MSE: {mse:.4f}, R^2: {r2:.4f}')
# Out:
# MSE: 0.0083, R^2: 0.2665

# %% [markdown]
# ## Pipelines

# %% [markdown]
# We can also do it in a more sklearn way, by defining a formula transformer and corresponding pipelines

# %%
class FormulaTransformer(TransformerMixin, BaseEstimator):

    def __init__(self, formula):
        self.formula = formula

    def fit(self, X, y=None):
        mat = patsy.dmatrix(self.formula, X, return_type='matrix')
        self.design_info = mat.design_info
        return self

    def transform(self, X, y=None):
        return patsy.build_design_matrices([self.design_info], X)[0]

# %%
base = FormulaTransformer(model_base)
methods = [('ols', make_pipeline(base, LinearRegression())),
           ('lasso', make_pipeline(base, StandardScaler(), RLasso(post=False))),
           ('postlasso', make_pipeline(base, StandardScaler(), RLasso(post=True))),
           ('lcv', make_pipeline(base, StandardScaler(), LassoCV())),
           ('rcv', make_pipeline(base, StandardScaler(), RidgeCV())),
           ('ecv', make_pipeline(base, StandardScaler(), ElasticNetCV())),
           ('dtr', make_pipeline(base, DecisionTreeRegressor(ccp_alpha=0.001, min_samples_leaf=5,
                                                             random_state=123))),
           ('rf', make_pipeline(base, RandomForestRegressor(n_estimators=2000, min_samples_leaf=5,
                                                            random_state=123))),
           ('gbf', make_pipeline(base, GradientBoostingRegressor(n_estimators=1000, learning_rate=.01,
                                                                 subsample=.5, max_depth=2,
                                                                 random_state=123))),
           ('nnet', make_pipeline(base, MLPRegressor((200, 20,), 'relu',
                                                     learning_rate_init=0.01,
                                                     batch_size=10, max_iter=10,
                                                     random_state=123)))]

# %%
results = {}
ypreds = np.zeros((len(test_idx), len(methods)))  # test predictions used for stacking

for it, (name, estimator) in enumerate(methods):
    estimator.fit(Z.iloc[train_idx], y[train_idx])
    results[name] = metrics(Z.iloc[test_idx], y[test_idx], estimator)
    ypreds[:, it] = estimator.predict(Z.iloc[test_idx])
# Out:
# 0.0086, 0.0007, 0.2342
# 0.0090, 0.0007, 0.2019
# 0.0091, 0.0007, 0.1977
# 0.0087, 0.0007, 0.2333
# 0.0086, 0.0007, 0.2343
# 0.0087, 0.0007, 0.2333
# 0.0113, 0.0008, -0.0005
# 0.0089, 0.0007, 0.2126
# 0.0088, 0.0007, 0.2226
# 0.0099, 0.0007, 0.1273

# %%
df = pd.DataFrame(results).T
df.columns = ['MSE', 'S.E. MSE', 'Rsq']
df
# Out:
#                 MSE  S.E. MSE       Rsq
# ols        0.008647  0.000701  0.234199
# lasso      0.009012  0.000728  0.201858
# postlasso  0.009059  0.000723  0.197714
# lcv        0.008657  0.000703  0.233345
# rcv        0.008646  0.000701  0.234312
# ecv        0.008657  0.000703  0.233332
# dtr        0.011298  0.000780 -0.000550
# rf         0.008892  0.000667  0.212551
# gbf        0.008779  0.000688  0.222555
# nnet       0.009854  0.000746  0.127279

# %% [markdown]
# 1. Partition the data in k-folds
#
# 2. For each fold, train each of the estimators in the `methods` parameter on all the data outside of the fold and then predict on the data in the fold
#
# 3. Train a `final_estimator` predicting the true outcome using the out-of-fold predictions of each method as features
#
# 4. All the base estimators are re-fitted on all the data and the final predictor will first predict based on each fitted based estimator and then aggregate based on the fitted `final_estimator`

# %%
# Stacking with sklearn
stack = StackingRegressor(methods, final_estimator=RLasso(), cv=3, verbose=3)
stack.fit(Z.iloc[train_idx], y[train_idx])
# Out:
# StackingRegressor(cv=3,
#                   estimators=[('ols',
#                                Pipeline(steps=[('formulatransformer',
#                                                 FormulaTransformer(formula='0 '
#                                                                            '+ '
#                                                                            'female '
#                                                                            '+ '
#                                                                            'age '
#                                                                            '+ '
#                                                                            'race '
#                                                                            '+ '
#                                                                            'children '
#                                                                            '+ '
#                                                                            'marital '
#                                                                            '+ '
#                                                                            'education '
#                                                                            '+ '
#                                                                            'RN_experience '
#                                                                            '+ '
#                                                                            'RN_experience**2 '
#                                                                            '+ '
#                                                                            'RN_experience**3 '
#                                                                            '+ '
#                                                                            'RN_experience**4 '
#                                                                            '+ '
#                                                                            'left_nursing '
#                                                                            '+ '
#                                                                            'country_ed_US '
#                                                                            '+ '
#                                                                            'english_only '
#                                                                            '+ '
#                                                                            'military '
#                                                                            '+ '
#                                                                            'certificates+ '
#                                                                            'labor_un...
#                                                                            'RN_experience**4 '
#                                                                            '+ '
#                                                                            'left_nursing '
#                                                                            '+ '
#                                                                            'country_ed_US '
#                                                                            '+ '
#                                                                            'english_only '
#                                                                            '+ '
#                                                                            'military '
#                                                                            '+ '
#                                                                            'certificates+ '
#                                                                            'labor_union '
#                                                                            '+ '
#                                                                            'work_setting '
#                                                                            '+ '
#                                                                            'work_situation '
#                                                                            '+ '
#                                                                            'level_care '
#                                                                            '+ '
#                                                                            'care_specialty '
#                                                                            '+ '
#                                                                            'state')),
#                                                ('mlpregressor',
#                                                 MLPRegressor(batch_size=10,
#                                                              hidden_layer_sizes=(200,
#                                                                                  20),
#                                                              learning_rate_init=0.01,
#                                                              max_iter=10,
#                                                              random_state=123))]))],
#                   final_estimator=RLasso(), verbose=3)

# %%
# Weights of the final estimator
pd.DataFrame({'weight': stack.final_estimator_.coef_}, index=[name for name, _ in methods])
# Out:
#              weight
# ols        1.767026
# lasso      0.000000
# postlasso  0.000000
# lcv        0.000000
# rcv       -1.205465
# ecv        0.000000
# dtr        0.000000
# rf         0.301635
# gbf        0.191599
# nnet       0.000000

# %%
# Out-of-sample performance
mse, semse, r2 = metrics(Z.iloc[test_idx], y[test_idx], stack)
# Out:
# 0.0084, 0.0007, 0.2579

# %% [markdown]
# ## AutoML

# %%
from flaml import AutoML

automl = make_pipeline(base, AutoML(task='regression', time_budget=60, early_stop=True,
                                    eval_method='cv', n_splits=3, metric='r2', verbose=3,))

automl.fit(Z.iloc[train_idx], y[train_idx])
# Out:
# [flaml.automl.logger: 07-31 17:25:22] {1680} INFO - task = regression
# [flaml.automl.logger: 07-31 17:25:22] {1691} INFO - Evaluation method: cv
# [flaml.automl.logger: 07-31 17:25:22] {1789} INFO - Minimizing error metric: 1-r2
# [flaml.automl.logger: 07-31 17:25:22] {1901} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth']
# [flaml.automl.logger: 07-31 17:25:22] {2219} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 07-31 17:25:22] {2345} INFO - Estimated sufficient time budget=384s. Estimated necessary time budget=3s.
# [flaml.automl.logger: 07-31 17:25:22] {2392} INFO -  at 0.0s,	estimator lgbm's best error=0.9308,	best estimator lgbm's best error=0.9308
# [flaml.automl.logger: 07-31 17:25:22] {2219} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 07-31 17:25:22] {2392} INFO -  at 0.1s,	estimator lgbm's best error=0.9308,	best estimator lgbm's best error=0.9308
# [flaml.automl.logger: 07-31 17:25:22] {2219} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 07-31 17:25:22] {2392} INFO -  at 0.1s,	estimator lgbm's best error=0.8760,	best estimator lgbm's best error=0.8760
# [flaml.automl.logger: 07-31 17:25:22] {2219} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 07-31 17:25:22] {2392} INFO -  at 0.1s,	estimator lgbm's best error=0.8000,	best estimator lgbm's best error=0.8000
# [flaml.automl.logger: 07-31 17:25:22] {2219} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 07-31 17:25:22] {2392} INFO -  at 0.2s,	estimator lgbm's best error=0.8000,	best estimator lgbm's best error=0.8000
# [flaml.automl.logger: 07-31 17:25:22] {2219} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 07-31 17:25:22] {2392} INFO -  at 0.2s,	estimator lgbm's best error=0.7946,	best estimator lgbm's best error=0.7946
# [flaml.automl.logger: 07-31 17:25:22] {2219} INFO - iteration 6, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:22] {2392} INFO -  at 0.3s,	estimator xgboost's best error=0.9308,	best estimator lgbm's best error=0.7946
# [flaml.automl.logger: 07-31 17:25:22] {2219} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 07-31 17:25:22] {2392} INFO -  at 0.4s,	estimator lgbm's best error=0.7946,	best estimator lgbm's best error=0.7946
# [flaml.automl.logger: 07-31 17:25:22] {2219} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 07-31 17:25:23] {2392} INFO -  at 0.4s,	estimator lgbm's best error=0.7946,	best estimator lgbm's best error=0.7946
# [flaml.automl.logger: 07-31 17:25:23] {2219} INFO - iteration 9, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:23] {2392} INFO -  at 0.5s,	estimator xgboost's best error=0.9308,	best estimator lgbm's best error=0.7946
# [flaml.automl.logger: 07-31 17:25:23] {2219} INFO - iteration 10, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:23] {2392} INFO -  at 0.5s,	estimator xgboost's best error=0.8799,	best estimator lgbm's best error=0.7946
# [flaml.automl.logger: 07-31 17:25:23] {2219} INFO - iteration 11, current learner extra_tree
# [flaml.automl.logger: 07-31 17:25:23] {2392} INFO -  at 0.6s,	estimator extra_tree's best error=0.8897,	best estimator lgbm's best error=0.7946
# [flaml.automl.logger: 07-31 17:25:23] {2219} INFO - iteration 12, current learner rf
# [flaml.automl.logger: 07-31 17:25:23] {2392} INFO -  at 0.7s,	estimator rf's best error=0.8821,	best estimator lgbm's best error=0.7946
# [flaml.automl.logger: 07-31 17:25:23] {2219} INFO - iteration 13, current learner rf
# [flaml.automl.logger: 07-31 17:25:23] {2392} INFO -  at 0.8s,	estimator rf's best error=0.8536,	best estimator lgbm's best error=0.7946
# [flaml.automl.logger: 07-31 17:25:23] {2219} INFO - iteration 14, current learner rf
# [flaml.automl.logger: 07-31 17:25:23] {2392} INFO -  at 0.9s,	estimator rf's best error=0.8536,	best estimator lgbm's best error=0.7946
# [flaml.automl.logger: 07-31 17:25:23] {2219} INFO - iteration 15, current learner extra_tree
# [flaml.automl.logger: 07-31 17:25:23] {2392} INFO -  at 1.0s,	estimator extra_tree's best error=0.8726,	best estimator lgbm's best error=0.7946
# [flaml.automl.logger: 07-31 17:25:23] {2219} INFO - iteration 16, current learner lgbm
# [flaml.automl.logger: 07-31 17:25:23] {2392} INFO -  at 1.1s,	estimator lgbm's best error=0.7818,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:25:23] {2219} INFO - iteration 17, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:23] {2392} INFO -  at 1.1s,	estimator xgboost's best error=0.8324,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:25:23] {2219} INFO - iteration 18, current learner lgbm
# [flaml.automl.logger: 07-31 17:25:23] {2392} INFO -  at 1.2s,	estimator lgbm's best error=0.7818,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:25:23] {2219} INFO - iteration 19, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:23] {2392} INFO -  at 1.2s,	estimator xgboost's best error=0.8324,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:25:23] {2219} INFO - iteration 20, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:23] {2392} INFO -  at 1.3s,	estimator xgboost's best error=0.8324,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:25:23] {2219} INFO - iteration 21, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:23] {2392} INFO -  at 1.3s,	estimator xgboost's best error=0.8164,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:25:23] {2219} INFO - iteration 22, current learner lgbm
# [flaml.automl.logger: 07-31 17:25:24] {2392} INFO -  at 1.8s,	estimator lgbm's best error=0.7818,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:25:24] {2219} INFO - iteration 23, current learner lgbm
# [flaml.automl.logger: 07-31 17:25:24] {2392} INFO -  at 1.9s,	estimator lgbm's best error=0.7818,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:25:24] {2219} INFO - iteration 24, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:24] {2392} INFO -  at 1.9s,	estimator xgboost's best error=0.8049,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:25:24] {2219} INFO - iteration 25, current learner extra_tree
# [flaml.automl.logger: 07-31 17:25:24] {2392} INFO -  at 2.0s,	estimator extra_tree's best error=0.8726,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:25:24] {2219} INFO - iteration 26, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:24] {2392} INFO -  at 2.1s,	estimator xgboost's best error=0.8049,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:25:24] {2219} INFO - iteration 27, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:24] {2392} INFO -  at 2.1s,	estimator xgboost's best error=0.8049,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:25:24] {2219} INFO - iteration 28, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:24] {2392} INFO -  at 2.2s,	estimator xgboost's best error=0.7887,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:25:24] {2219} INFO - iteration 29, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:24] {2392} INFO -  at 2.2s,	estimator xgboost's best error=0.7887,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:25:24] {2219} INFO - iteration 30, current learner lgbm
# [flaml.automl.logger: 07-31 17:25:24] {2392} INFO -  at 2.3s,	estimator lgbm's best error=0.7818,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:25:24] {2219} INFO - iteration 31, current learner lgbm
# [flaml.automl.logger: 07-31 17:25:25] {2392} INFO -  at 2.4s,	estimator lgbm's best error=0.7818,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:25:25] {2219} INFO - iteration 32, current learner rf
# [flaml.automl.logger: 07-31 17:25:25] {2392} INFO -  at 2.6s,	estimator rf's best error=0.8443,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:25:25] {2219} INFO - iteration 33, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:25] {2392} INFO -  at 2.6s,	estimator xgboost's best error=0.7641,	best estimator xgboost's best error=0.7641
# [flaml.automl.logger: 07-31 17:25:25] {2219} INFO - iteration 34, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:25] {2392} INFO -  at 2.7s,	estimator xgboost's best error=0.7641,	best estimator xgboost's best error=0.7641
# [flaml.automl.logger: 07-31 17:25:25] {2219} INFO - iteration 35, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:25] {2392} INFO -  at 2.7s,	estimator xgboost's best error=0.7641,	best estimator xgboost's best error=0.7641
# [flaml.automl.logger: 07-31 17:25:25] {2219} INFO - iteration 36, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:25] {2392} INFO -  at 2.8s,	estimator xgboost's best error=0.7641,	best estimator xgboost's best error=0.7641
# [flaml.automl.logger: 07-31 17:25:25] {2219} INFO - iteration 37, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:25] {2392} INFO -  at 2.9s,	estimator xgboost's best error=0.7641,	best estimator xgboost's best error=0.7641
# [flaml.automl.logger: 07-31 17:25:25] {2219} INFO - iteration 38, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:25] {2392} INFO -  at 3.0s,	estimator xgboost's best error=0.7641,	best estimator xgboost's best error=0.7641
# [flaml.automl.logger: 07-31 17:25:25] {2219} INFO - iteration 39, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:25] {2392} INFO -  at 3.1s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:25] {2219} INFO - iteration 40, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:25] {2392} INFO -  at 3.1s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:25] {2219} INFO - iteration 41, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:26] {2392} INFO -  at 3.6s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:26] {2219} INFO - iteration 42, current learner lgbm
# [flaml.automl.logger: 07-31 17:25:26] {2392} INFO -  at 3.8s,	estimator lgbm's best error=0.7798,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:26] {2219} INFO - iteration 43, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:26] {2392} INFO -  at 3.9s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:26] {2219} INFO - iteration 44, current learner extra_tree
# [flaml.automl.logger: 07-31 17:25:26] {2392} INFO -  at 4.0s,	estimator extra_tree's best error=0.8526,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:26] {2219} INFO - iteration 45, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:26] {2392} INFO -  at 4.2s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:26] {2219} INFO - iteration 46, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:26] {2392} INFO -  at 4.3s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:26] {2219} INFO - iteration 47, current learner extra_tree
# [flaml.automl.logger: 07-31 17:25:27] {2392} INFO -  at 4.4s,	estimator extra_tree's best error=0.8526,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:27] {2219} INFO - iteration 48, current learner rf
# [flaml.automl.logger: 07-31 17:25:27] {2392} INFO -  at 4.5s,	estimator rf's best error=0.8443,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:27] {2219} INFO - iteration 49, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:27] {2392} INFO -  at 4.7s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:27] {2219} INFO - iteration 50, current learner extra_tree
# [flaml.automl.logger: 07-31 17:25:27] {2392} INFO -  at 4.8s,	estimator extra_tree's best error=0.8526,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:27] {2219} INFO - iteration 51, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:27] {2392} INFO -  at 4.8s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:27] {2219} INFO - iteration 52, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:27] {2392} INFO -  at 5.3s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:27] {2219} INFO - iteration 53, current learner rf
# [flaml.automl.logger: 07-31 17:25:28] {2392} INFO -  at 5.4s,	estimator rf's best error=0.8443,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:28] {2219} INFO - iteration 54, current learner lgbm
# [flaml.automl.logger: 07-31 17:25:28] {2392} INFO -  at 5.7s,	estimator lgbm's best error=0.7798,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:28] {2219} INFO - iteration 55, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:28] {2392} INFO -  at 5.8s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:28] {2219} INFO - iteration 56, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:28] {2392} INFO -  at 6.0s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:28] {2219} INFO - iteration 57, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:28] {2392} INFO -  at 6.1s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:28] {2219} INFO - iteration 58, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:28] {2392} INFO -  at 6.3s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:28] {2219} INFO - iteration 59, current learner rf
# [flaml.automl.logger: 07-31 17:25:29] {2392} INFO -  at 6.5s,	estimator rf's best error=0.8443,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:29] {2219} INFO - iteration 60, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:29] {2392} INFO -  at 6.6s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:29] {2219} INFO - iteration 61, current learner rf
# [flaml.automl.logger: 07-31 17:25:29] {2392} INFO -  at 6.8s,	estimator rf's best error=0.8443,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:29] {2219} INFO - iteration 62, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:29] {2392} INFO -  at 6.9s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:29] {2219} INFO - iteration 63, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:29] {2392} INFO -  at 7.0s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:29] {2219} INFO - iteration 64, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:25:29] {2392} INFO -  at 7.0s,	estimator xgb_limitdepth's best error=0.8130,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:29] {2219} INFO - iteration 65, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:25:29] {2392} INFO -  at 7.1s,	estimator xgb_limitdepth's best error=0.8130,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:29] {2219} INFO - iteration 66, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:25:29] {2392} INFO -  at 7.1s,	estimator xgb_limitdepth's best error=0.8130,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:29] {2219} INFO - iteration 67, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:25:29] {2392} INFO -  at 7.2s,	estimator xgb_limitdepth's best error=0.8130,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:29] {2219} INFO - iteration 68, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:25:29] {2392} INFO -  at 7.2s,	estimator xgb_limitdepth's best error=0.8130,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:29] {2219} INFO - iteration 69, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:29] {2392} INFO -  at 7.3s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:29] {2219} INFO - iteration 70, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:25:29] {2392} INFO -  at 7.3s,	estimator xgb_limitdepth's best error=0.8130,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:29] {2219} INFO - iteration 71, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:25:30] {2392} INFO -  at 7.4s,	estimator xgb_limitdepth's best error=0.8130,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:30] {2219} INFO - iteration 72, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:25:30] {2392} INFO -  at 7.5s,	estimator xgb_limitdepth's best error=0.8130,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:30] {2219} INFO - iteration 73, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:25:30] {2392} INFO -  at 7.5s,	estimator xgb_limitdepth's best error=0.8130,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:30] {2219} INFO - iteration 74, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:25:30] {2392} INFO -  at 7.5s,	estimator xgb_limitdepth's best error=0.8023,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:30] {2219} INFO - iteration 75, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:25:30] {2392} INFO -  at 7.6s,	estimator xgb_limitdepth's best error=0.7963,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:30] {2219} INFO - iteration 76, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:30] {2392} INFO -  at 7.9s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:30] {2219} INFO - iteration 77, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:30] {2392} INFO -  at 8.0s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:30] {2219} INFO - iteration 78, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:25:30] {2392} INFO -  at 8.1s,	estimator xgb_limitdepth's best error=0.7963,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:30] {2219} INFO - iteration 79, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:25:30] {2392} INFO -  at 8.1s,	estimator xgb_limitdepth's best error=0.7963,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:30] {2219} INFO - iteration 80, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:30] {2392} INFO -  at 8.2s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:30] {2219} INFO - iteration 81, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:25:30] {2392} INFO -  at 8.3s,	estimator xgb_limitdepth's best error=0.7963,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:30] {2219} INFO - iteration 82, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:30] {2392} INFO -  at 8.4s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:30] {2219} INFO - iteration 83, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:25:31] {2392} INFO -  at 8.6s,	estimator xgb_limitdepth's best error=0.7963,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:31] {2219} INFO - iteration 84, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:25:31] {2392} INFO -  at 8.6s,	estimator xgb_limitdepth's best error=0.7963,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:31] {2219} INFO - iteration 85, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:25:31] {2392} INFO -  at 8.7s,	estimator xgb_limitdepth's best error=0.7963,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:31] {2219} INFO - iteration 86, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:31] {2392} INFO -  at 8.8s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:31] {2219} INFO - iteration 87, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:25:31] {2392} INFO -  at 8.8s,	estimator xgb_limitdepth's best error=0.7963,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:31] {2219} INFO - iteration 88, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:31] {2392} INFO -  at 8.9s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:31] {2219} INFO - iteration 89, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:31] {2392} INFO -  at 9.0s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:31] {2219} INFO - iteration 90, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:25:31] {2392} INFO -  at 9.0s,	estimator xgb_limitdepth's best error=0.7963,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:31] {2219} INFO - iteration 91, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:31] {2392} INFO -  at 9.4s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:31] {2219} INFO - iteration 92, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:25:32] {2392} INFO -  at 9.4s,	estimator xgb_limitdepth's best error=0.7963,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:32] {2219} INFO - iteration 93, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:32] {2392} INFO -  at 9.5s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:32] {2219} INFO - iteration 94, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:32] {2392} INFO -  at 9.6s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:32] {2219} INFO - iteration 95, current learner rf
# [flaml.automl.logger: 07-31 17:25:32] {2392} INFO -  at 9.8s,	estimator rf's best error=0.8271,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:32] {2219} INFO - iteration 96, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:25:32] {2392} INFO -  at 9.9s,	estimator xgb_limitdepth's best error=0.7876,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:32] {2219} INFO - iteration 97, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:32] {2392} INFO -  at 10.1s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:32] {2219} INFO - iteration 98, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:32] {2392} INFO -  at 10.1s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:32] {2219} INFO - iteration 99, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:32] {2392} INFO -  at 10.2s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:32] {2219} INFO - iteration 100, current learner rf
# [flaml.automl.logger: 07-31 17:25:32] {2392} INFO -  at 10.4s,	estimator rf's best error=0.8271,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:32] {2219} INFO - iteration 101, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:25:33] {2392} INFO -  at 10.4s,	estimator xgb_limitdepth's best error=0.7876,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:33] {2219} INFO - iteration 102, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:33] {2392} INFO -  at 10.5s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:33] {2219} INFO - iteration 103, current learner lgbm
# [flaml.automl.logger: 07-31 17:25:33] {2392} INFO -  at 10.7s,	estimator lgbm's best error=0.7798,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:25:33] {2219} INFO - iteration 104, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:33] {2392} INFO -  at 10.8s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:33] {2219} INFO - iteration 105, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:33] {2392} INFO -  at 10.9s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:33] {2219} INFO - iteration 106, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:33] {2392} INFO -  at 11.2s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:33] {2219} INFO - iteration 107, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:25:33] {2392} INFO -  at 11.3s,	estimator xgb_limitdepth's best error=0.7876,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:33] {2219} INFO - iteration 108, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:33] {2392} INFO -  at 11.4s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:33] {2219} INFO - iteration 109, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:25:34] {2392} INFO -  at 11.4s,	estimator xgb_limitdepth's best error=0.7876,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:34] {2219} INFO - iteration 110, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:34] {2392} INFO -  at 11.7s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:34] {2219} INFO - iteration 111, current learner lgbm
# [flaml.automl.logger: 07-31 17:25:34] {2392} INFO -  at 12.0s,	estimator lgbm's best error=0.7798,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:34] {2219} INFO - iteration 112, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:25:34] {2392} INFO -  at 12.1s,	estimator xgb_limitdepth's best error=0.7876,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:34] {2219} INFO - iteration 113, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:34] {2392} INFO -  at 12.3s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:34] {2219} INFO - iteration 114, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:25:34] {2392} INFO -  at 12.3s,	estimator xgb_limitdepth's best error=0.7876,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:34] {2219} INFO - iteration 115, current learner rf
# [flaml.automl.logger: 07-31 17:25:35] {2392} INFO -  at 12.5s,	estimator rf's best error=0.8255,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:35] {2219} INFO - iteration 116, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:35] {2392} INFO -  at 12.7s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:35] {2219} INFO - iteration 117, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:25:35] {2392} INFO -  at 12.9s,	estimator xgb_limitdepth's best error=0.7874,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:35] {2219} INFO - iteration 118, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:35] {2392} INFO -  at 13.0s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:35] {2219} INFO - iteration 119, current learner lgbm
# [flaml.automl.logger: 07-31 17:25:35] {2392} INFO -  at 13.2s,	estimator lgbm's best error=0.7797,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:35] {2219} INFO - iteration 120, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:36] {2392} INFO -  at 13.4s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:36] {2219} INFO - iteration 121, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:36] {2392} INFO -  at 13.5s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:36] {2219} INFO - iteration 122, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:36] {2392} INFO -  at 13.7s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:36] {2219} INFO - iteration 123, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:36] {2392} INFO -  at 13.9s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:36] {2219} INFO - iteration 124, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:36] {2392} INFO -  at 14.2s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:36] {2219} INFO - iteration 125, current learner rf
# [flaml.automl.logger: 07-31 17:25:36] {2392} INFO -  at 14.3s,	estimator rf's best error=0.8255,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:36] {2219} INFO - iteration 126, current learner rf
# [flaml.automl.logger: 07-31 17:25:37] {2392} INFO -  at 14.8s,	estimator rf's best error=0.8138,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:37] {2219} INFO - iteration 127, current learner rf
# [flaml.automl.logger: 07-31 17:25:37] {2392} INFO -  at 15.1s,	estimator rf's best error=0.8138,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:37] {2219} INFO - iteration 128, current learner rf
# [flaml.automl.logger: 07-31 17:25:38] {2392} INFO -  at 16.0s,	estimator rf's best error=0.8048,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:38] {2219} INFO - iteration 129, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:38] {2392} INFO -  at 16.1s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:38] {2219} INFO - iteration 130, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:38] {2392} INFO -  at 16.2s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:38] {2219} INFO - iteration 131, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:38] {2392} INFO -  at 16.4s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:38] {2219} INFO - iteration 132, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:39] {2392} INFO -  at 16.4s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:39] {2219} INFO - iteration 133, current learner rf
# [flaml.automl.logger: 07-31 17:25:39] {2392} INFO -  at 16.8s,	estimator rf's best error=0.8048,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:39] {2219} INFO - iteration 134, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:40] {2392} INFO -  at 17.4s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:40] {2219} INFO - iteration 135, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:40] {2392} INFO -  at 17.6s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:40] {2219} INFO - iteration 136, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:40] {2392} INFO -  at 17.7s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:40] {2219} INFO - iteration 137, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:40] {2392} INFO -  at 18.1s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:40] {2219} INFO - iteration 138, current learner rf
# [flaml.automl.logger: 07-31 17:25:42] {2392} INFO -  at 19.9s,	estimator rf's best error=0.8048,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:42] {2219} INFO - iteration 139, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:42] {2392} INFO -  at 20.0s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:42] {2219} INFO - iteration 140, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:42] {2392} INFO -  at 20.2s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:42] {2219} INFO - iteration 141, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:42] {2392} INFO -  at 20.4s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:42] {2219} INFO - iteration 142, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:43] {2392} INFO -  at 20.6s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:43] {2219} INFO - iteration 143, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:43] {2392} INFO -  at 20.7s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:43] {2219} INFO - iteration 144, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:43] {2392} INFO -  at 21.0s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:43] {2219} INFO - iteration 145, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:43] {2392} INFO -  at 21.1s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:43] {2219} INFO - iteration 146, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:43] {2392} INFO -  at 21.3s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:43] {2219} INFO - iteration 147, current learner rf
# [flaml.automl.logger: 07-31 17:25:45] {2392} INFO -  at 23.1s,	estimator rf's best error=0.8024,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:45] {2219} INFO - iteration 148, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:45] {2392} INFO -  at 23.2s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:45] {2219} INFO - iteration 149, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:46] {2392} INFO -  at 23.5s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:46] {2219} INFO - iteration 150, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:46] {2392} INFO -  at 23.6s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:46] {2219} INFO - iteration 151, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:46] {2392} INFO -  at 23.7s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:46] {2219} INFO - iteration 152, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:46] {2392} INFO -  at 24.0s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:46] {2219} INFO - iteration 153, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:46] {2392} INFO -  at 24.2s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:46] {2219} INFO - iteration 154, current learner rf
# [flaml.automl.logger: 07-31 17:25:47] {2392} INFO -  at 25.1s,	estimator rf's best error=0.8024,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:47] {2219} INFO - iteration 155, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:47] {2392} INFO -  at 25.2s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:47] {2219} INFO - iteration 156, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:47] {2392} INFO -  at 25.4s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:47] {2219} INFO - iteration 157, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:48] {2392} INFO -  at 25.6s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:48] {2219} INFO - iteration 158, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:48] {2392} INFO -  at 25.9s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:48] {2219} INFO - iteration 159, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:48] {2392} INFO -  at 26.0s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:48] {2219} INFO - iteration 160, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:48] {2392} INFO -  at 26.2s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:48] {2219} INFO - iteration 161, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:48] {2392} INFO -  at 26.3s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:48] {2219} INFO - iteration 162, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:49] {2392} INFO -  at 26.4s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:49] {2219} INFO - iteration 163, current learner extra_tree
# [flaml.automl.logger: 07-31 17:25:49] {2392} INFO -  at 26.6s,	estimator extra_tree's best error=0.8526,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:49] {2219} INFO - iteration 164, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:49] {2392} INFO -  at 26.7s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:49] {2219} INFO - iteration 165, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:49] {2392} INFO -  at 26.8s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:49] {2219} INFO - iteration 166, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:49] {2392} INFO -  at 27.0s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:49] {2219} INFO - iteration 167, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:50] {2392} INFO -  at 27.4s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:50] {2219} INFO - iteration 168, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:50] {2392} INFO -  at 27.6s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:50] {2219} INFO - iteration 169, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:50] {2392} INFO -  at 27.8s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:50] {2219} INFO - iteration 170, current learner rf
# [flaml.automl.logger: 07-31 17:25:53] {2392} INFO -  at 31.1s,	estimator rf's best error=0.8024,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:53] {2219} INFO - iteration 171, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:53] {2392} INFO -  at 31.3s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:53] {2219} INFO - iteration 172, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:54] {2392} INFO -  at 31.7s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:54] {2219} INFO - iteration 173, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:54] {2392} INFO -  at 31.8s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:54] {2219} INFO - iteration 174, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:55] {2392} INFO -  at 32.5s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:55] {2219} INFO - iteration 175, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:55] {2392} INFO -  at 32.5s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:55] {2219} INFO - iteration 176, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:25:55] {2392} INFO -  at 32.7s,	estimator xgb_limitdepth's best error=0.7874,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:55] {2219} INFO - iteration 177, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:55] {2392} INFO -  at 32.9s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:55] {2219} INFO - iteration 178, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:55] {2392} INFO -  at 33.3s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:55] {2219} INFO - iteration 179, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:56] {2392} INFO -  at 33.4s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:56] {2219} INFO - iteration 180, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:56] {2392} INFO -  at 33.8s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:56] {2219} INFO - iteration 181, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:56] {2392} INFO -  at 33.9s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:56] {2219} INFO - iteration 182, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:56] {2392} INFO -  at 34.4s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:56] {2219} INFO - iteration 183, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:57] {2392} INFO -  at 34.5s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:57] {2219} INFO - iteration 184, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:57] {2392} INFO -  at 34.7s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:57] {2219} INFO - iteration 185, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:57] {2392} INFO -  at 34.8s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:57] {2219} INFO - iteration 186, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:58] {2392} INFO -  at 35.4s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:58] {2219} INFO - iteration 187, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:58] {2392} INFO -  at 36.0s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:58] {2219} INFO - iteration 188, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:58] {2392} INFO -  at 36.1s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:58] {2219} INFO - iteration 189, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:58] {2392} INFO -  at 36.1s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:58] {2219} INFO - iteration 190, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:59] {2392} INFO -  at 36.5s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:59] {2219} INFO - iteration 191, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:59] {2392} INFO -  at 36.7s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:59] {2219} INFO - iteration 192, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:59] {2392} INFO -  at 36.8s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:59] {2219} INFO - iteration 193, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:59] {2392} INFO -  at 36.9s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:59] {2219} INFO - iteration 194, current learner xgboost
# [flaml.automl.logger: 07-31 17:25:59] {2392} INFO -  at 37.3s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:25:59] {2219} INFO - iteration 195, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:00] {2392} INFO -  at 37.4s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:00] {2219} INFO - iteration 196, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:00] {2392} INFO -  at 37.9s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:00] {2219} INFO - iteration 197, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:00] {2392} INFO -  at 38.1s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:00] {2219} INFO - iteration 198, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:00] {2392} INFO -  at 38.3s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:00] {2219} INFO - iteration 199, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:01] {2392} INFO -  at 38.4s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:01] {2219} INFO - iteration 200, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:01] {2392} INFO -  at 38.8s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:01] {2219} INFO - iteration 201, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:01] {2392} INFO -  at 38.9s,	estimator lgbm's best error=0.7797,	best estimator xgboost's best error=0.7511
# ...
# [flaml.automl.logger: 07-31 17:26:09] {2392} INFO -  at 46.8s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:09] {2219} INFO - iteration 235, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:09] {2392} INFO -  at 47.1s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:09] {2219} INFO - iteration 236, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:09] {2392} INFO -  at 47.3s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:09] {2219} INFO - iteration 237, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:09] {2392} INFO -  at 47.4s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:09] {2219} INFO - iteration 238, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:10] {2392} INFO -  at 47.7s,	estimator lgbm's best error=0.7651,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:10] {2219} INFO - iteration 239, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:10] {2392} INFO -  at 48.3s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:10] {2219} INFO - iteration 240, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:11] {2392} INFO -  at 48.4s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:11] {2219} INFO - iteration 241, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:11] {2392} INFO -  at 48.5s,	estimator lgbm's best error=0.7651,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:11] {2219} INFO - iteration 242, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:11] {2392} INFO -  at 48.9s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:11] {2219} INFO - iteration 243, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:11] {2392} INFO -  at 49.1s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:11] {2219} INFO - iteration 244, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:11] {2392} INFO -  at 49.2s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:11] {2219} INFO - iteration 245, current learner rf
# [flaml.automl.logger: 07-31 17:26:12] {2392} INFO -  at 50.3s,	estimator rf's best error=0.8024,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:12] {2219} INFO - iteration 246, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:13] {2392} INFO -  at 50.7s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:13] {2219} INFO - iteration 247, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:13] {2392} INFO -  at 50.8s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:13] {2219} INFO - iteration 248, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:13] {2392} INFO -  at 50.9s,	estimator lgbm's best error=0.7651,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:13] {2219} INFO - iteration 249, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:13] {2392} INFO -  at 51.1s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:13] {2219} INFO - iteration 250, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:13] {2392} INFO -  at 51.3s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:13] {2219} INFO - iteration 251, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:14] {2392} INFO -  at 51.8s,	estimator lgbm's best error=0.7651,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:14] {2219} INFO - iteration 252, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:14] {2392} INFO -  at 52.4s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:14] {2219} INFO - iteration 253, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:15] {2392} INFO -  at 52.5s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:15] {2219} INFO - iteration 254, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:15] {2392} INFO -  at 52.8s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:15] {2219} INFO - iteration 255, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:15] {2392} INFO -  at 53.0s,	estimator lgbm's best error=0.7651,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:15] {2219} INFO - iteration 256, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:26:15] {2392} INFO -  at 53.2s,	estimator xgb_limitdepth's best error=0.7874,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:15] {2219} INFO - iteration 257, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:15] {2392} INFO -  at 53.3s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:15] {2219} INFO - iteration 258, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:26:16] {2392} INFO -  at 54.0s,	estimator xgb_limitdepth's best error=0.7874,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:16] {2219} INFO - iteration 259, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:16] {2392} INFO -  at 54.1s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:16] {2219} INFO - iteration 260, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:16] {2392} INFO -  at 54.3s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:16] {2219} INFO - iteration 261, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:17] {2392} INFO -  at 54.4s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:17] {2219} INFO - iteration 262, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:17] {2392} INFO -  at 54.7s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:17] {2219} INFO - iteration 263, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:17] {2392} INFO -  at 54.8s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:17] {2219} INFO - iteration 264, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:17] {2392} INFO -  at 55.0s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:17] {2219} INFO - iteration 265, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:17] {2392} INFO -  at 55.3s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:17] {2219} INFO - iteration 266, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:18] {2392} INFO -  at 55.4s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:18] {2219} INFO - iteration 267, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:18] {2392} INFO -  at 55.7s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:18] {2219} INFO - iteration 268, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:18] {2392} INFO -  at 55.8s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:18] {2219} INFO - iteration 269, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:18] {2392} INFO -  at 56.1s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:18] {2219} INFO - iteration 270, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:18] {2392} INFO -  at 56.2s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:18] {2219} INFO - iteration 271, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:18] {2392} INFO -  at 56.4s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:18] {2219} INFO - iteration 272, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:19] {2392} INFO -  at 56.5s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:19] {2219} INFO - iteration 273, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:19] {2392} INFO -  at 56.7s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:19] {2219} INFO - iteration 274, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:19] {2392} INFO -  at 56.9s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:19] {2219} INFO - iteration 275, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:19] {2392} INFO -  at 57.1s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:19] {2219} INFO - iteration 276, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:19] {2392} INFO -  at 57.2s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:19] {2219} INFO - iteration 277, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:19] {2392} INFO -  at 57.2s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:19] {2219} INFO - iteration 278, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:20] {2392} INFO -  at 57.7s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:20] {2219} INFO - iteration 279, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:20] {2392} INFO -  at 57.9s,	estimator extra_tree's best error=0.8481,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:20] {2219} INFO - iteration 280, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:20] {2392} INFO -  at 58.0s,	estimator extra_tree's best error=0.8481,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:20] {2219} INFO - iteration 281, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:20] {2392} INFO -  at 58.2s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:20] {2219} INFO - iteration 282, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:20] {2392} INFO -  at 58.3s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:20] {2219} INFO - iteration 283, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:21] {2392} INFO -  at 58.9s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:21] {2219} INFO - iteration 284, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:21] {2392} INFO -  at 59.0s,	estimator extra_tree's best error=0.8481,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:21] {2219} INFO - iteration 285, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:21] {2392} INFO -  at 59.2s,	estimator extra_tree's best error=0.8481,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:21] {2219} INFO - iteration 286, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:21] {2392} INFO -  at 59.3s,	estimator extra_tree's best error=0.8481,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:21] {2219} INFO - iteration 287, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:22] {2392} INFO -  at 59.5s,	estimator extra_tree's best error=0.8481,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:22] {2219} INFO - iteration 288, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:22] {2392} INFO -  at 59.6s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:22] {2219} INFO - iteration 289, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:22] {2392} INFO -  at 59.8s,	estimator xgboost's best error=0.7511,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:22] {2219} INFO - iteration 290, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:22] {2392} INFO -  at 59.9s,	estimator extra_tree's best error=0.8481,	best estimator xgboost's best error=0.7511
# [flaml.automl.logger: 07-31 17:26:22] {2628} INFO - retrain xgboost for 0.1s
# [flaml.automl.logger: 07-31 17:26:22] {2631} INFO - retrained model: XGBRegressor(base_score=None, booster=None, callbacks=[],
#              colsample_bylevel=0.7095665844126344, colsample_bynode=None,
#              colsample_bytree=0.7308928497902272, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=None,
#              grow_policy='lossguide', importance_type=None,
#              interaction_constraints=None, learning_rate=0.17728441219865781,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=0, max_leaves=4,
#              min_child_weight=23.02191033028272, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=119,
#              n_jobs=-1, num_parallel_tree=None, random_state=None, ...)
# [flaml.automl.logger: 07-31 17:26:22] {1931} INFO - fit succeeded
# [flaml.automl.logger: 07-31 17:26:22] {1932} INFO - Time taken to find the best model: 10.797080993652344
# Pipeline(steps=[('formulatransformer',
#                  FormulaTransformer(formula='0 + female + age + race + '
#                                             'children + marital + education + '
#                                             'RN_experience + RN_experience**2 '
#                                             '+ RN_experience**3 + '
#                                             'RN_experience**4 + left_nursing + '
#                                             'country_ed_US + english_only + '
#                                             'military + certificates+ '
#                                             'labor_union + work_setting + '
#                                             'work_situation + level_care + '
#                                             'care_specialty + state')),
#                 ('automl',
#                  AutoML(ap...
#                         keep_search_state=False, learner_selector='sample',
#                         log_file_name='', log_training_metric=False,
#                         log_type='better', max_iter=None, mem_thres=4294967296,
#                         metric='r2', metric_constraints=[],
#                         min_sample_size=10000, mlflow_logging=True,
#                         model_history=False, n_concurrent_trials=1, n_jobs=-1,
#                         n_splits=3, pred_time_limit=inf,
#                         preserve_checkpoint=True, retrain_full=True, ...))])

# %%
# Out-of-sample performance
mse, semse, r2 = metrics(Z.iloc[test_idx], y[test_idx], automl)
# Out:
# 0.0085, 0.0007, 0.2451

# %%
# Stacking with flaml
automl = make_pipeline(base, AutoML(task='regression', time_budget=60, early_stop=True,
                                    eval_method='cv', n_splits=3, metric='r2', verbose=3,
                                    ensemble={'passthrough': False,  # stacker will use raw X's instead of predictions
                                              'final_estimator': RLasso()}))

automl.fit(Z.iloc[train_idx], y[train_idx])
# Out:
# [flaml.automl.logger: 07-31 17:26:22] {1680} INFO - task = regression
# [flaml.automl.logger: 07-31 17:26:22] {1691} INFO - Evaluation method: cv
# [flaml.automl.logger: 07-31 17:26:22] {1789} INFO - Minimizing error metric: 1-r2
# [flaml.automl.logger: 07-31 17:26:22] {1901} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth']
# [flaml.automl.logger: 07-31 17:26:22] {2219} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:22] {2345} INFO - Estimated sufficient time budget=369s. Estimated necessary time budget=3s.
# [flaml.automl.logger: 07-31 17:26:22] {2392} INFO -  at 0.0s,	estimator lgbm's best error=0.9308,	best estimator lgbm's best error=0.9308
# [flaml.automl.logger: 07-31 17:26:22] {2219} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:22] {2392} INFO -  at 0.1s,	estimator lgbm's best error=0.9308,	best estimator lgbm's best error=0.9308
# [flaml.automl.logger: 07-31 17:26:22] {2219} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:23] {2392} INFO -  at 0.1s,	estimator lgbm's best error=0.8760,	best estimator lgbm's best error=0.8760
# [flaml.automl.logger: 07-31 17:26:23] {2219} INFO - iteration 3, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:23] {2392} INFO -  at 0.2s,	estimator xgboost's best error=0.9308,	best estimator lgbm's best error=0.8760
# [flaml.automl.logger: 07-31 17:26:23] {2219} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:23] {2392} INFO -  at 0.2s,	estimator lgbm's best error=0.8000,	best estimator lgbm's best error=0.8000
# [flaml.automl.logger: 07-31 17:26:23] {2219} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:23] {2392} INFO -  at 0.3s,	estimator lgbm's best error=0.8000,	best estimator lgbm's best error=0.8000
# [flaml.automl.logger: 07-31 17:26:23] {2219} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:23] {2392} INFO -  at 0.4s,	estimator lgbm's best error=0.7946,	best estimator lgbm's best error=0.7946
# [flaml.automl.logger: 07-31 17:26:23] {2219} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:23] {2392} INFO -  at 0.4s,	estimator lgbm's best error=0.7946,	best estimator lgbm's best error=0.7946
# [flaml.automl.logger: 07-31 17:26:23] {2219} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:23] {2392} INFO -  at 0.4s,	estimator lgbm's best error=0.7946,	best estimator lgbm's best error=0.7946
# [flaml.automl.logger: 07-31 17:26:23] {2219} INFO - iteration 9, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:23] {2392} INFO -  at 0.5s,	estimator xgboost's best error=0.9308,	best estimator lgbm's best error=0.7946
# [flaml.automl.logger: 07-31 17:26:23] {2219} INFO - iteration 10, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:23] {2392} INFO -  at 0.5s,	estimator xgboost's best error=0.8799,	best estimator lgbm's best error=0.7946
# [flaml.automl.logger: 07-31 17:26:23] {2219} INFO - iteration 11, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:23] {2392} INFO -  at 0.6s,	estimator extra_tree's best error=0.8897,	best estimator lgbm's best error=0.7946
# [flaml.automl.logger: 07-31 17:26:23] {2219} INFO - iteration 12, current learner rf
# [flaml.automl.logger: 07-31 17:26:23] {2392} INFO -  at 0.7s,	estimator rf's best error=0.8821,	best estimator lgbm's best error=0.7946
# [flaml.automl.logger: 07-31 17:26:23] {2219} INFO - iteration 13, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:23] {2392} INFO -  at 0.8s,	estimator xgboost's best error=0.8324,	best estimator lgbm's best error=0.7946
# [flaml.automl.logger: 07-31 17:26:23] {2219} INFO - iteration 14, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:23] {2392} INFO -  at 0.8s,	estimator xgboost's best error=0.8324,	best estimator lgbm's best error=0.7946
# [flaml.automl.logger: 07-31 17:26:23] {2219} INFO - iteration 15, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:23] {2392} INFO -  at 0.9s,	estimator xgboost's best error=0.8324,	best estimator lgbm's best error=0.7946
# [flaml.automl.logger: 07-31 17:26:23] {2219} INFO - iteration 16, current learner rf
# [flaml.automl.logger: 07-31 17:26:23] {2392} INFO -  at 1.0s,	estimator rf's best error=0.8536,	best estimator lgbm's best error=0.7946
# [flaml.automl.logger: 07-31 17:26:23] {2219} INFO - iteration 17, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:23] {2392} INFO -  at 1.1s,	estimator extra_tree's best error=0.8726,	best estimator lgbm's best error=0.7946
# [flaml.automl.logger: 07-31 17:26:23] {2219} INFO - iteration 18, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:24] {2392} INFO -  at 1.2s,	estimator lgbm's best error=0.7818,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:26:24] {2219} INFO - iteration 19, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:24] {2392} INFO -  at 1.2s,	estimator xgboost's best error=0.8164,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:26:24] {2219} INFO - iteration 20, current learner rf
# [flaml.automl.logger: 07-31 17:26:24] {2392} INFO -  at 1.3s,	estimator rf's best error=0.8536,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:26:24] {2219} INFO - iteration 21, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:24] {2392} INFO -  at 1.3s,	estimator xgboost's best error=0.8049,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:26:24] {2219} INFO - iteration 22, current learner rf
# [flaml.automl.logger: 07-31 17:26:24] {2392} INFO -  at 1.5s,	estimator rf's best error=0.8443,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:26:24] {2219} INFO - iteration 23, current learner rf
# [flaml.automl.logger: 07-31 17:26:24] {2392} INFO -  at 1.6s,	estimator rf's best error=0.8443,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:26:24] {2219} INFO - iteration 24, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:24] {2392} INFO -  at 1.7s,	estimator extra_tree's best error=0.8726,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:26:24] {2219} INFO - iteration 25, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:24] {2392} INFO -  at 1.8s,	estimator extra_tree's best error=0.8526,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:26:24] {2219} INFO - iteration 26, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:24] {2392} INFO -  at 1.9s,	estimator xgboost's best error=0.8049,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:26:24] {2219} INFO - iteration 27, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:24] {2392} INFO -  at 1.9s,	estimator xgboost's best error=0.8049,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:26:24] {2219} INFO - iteration 28, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:24] {2392} INFO -  at 2.1s,	estimator extra_tree's best error=0.8526,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:26:24] {2219} INFO - iteration 29, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:25] {2392} INFO -  at 2.2s,	estimator extra_tree's best error=0.8526,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:26:25] {2219} INFO - iteration 30, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:25] {2392} INFO -  at 2.2s,	estimator lgbm's best error=0.7818,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:26:25] {2219} INFO - iteration 31, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:25] {2392} INFO -  at 2.6s,	estimator lgbm's best error=0.7818,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:26:25] {2219} INFO - iteration 32, current learner rf
# [flaml.automl.logger: 07-31 17:26:25] {2392} INFO -  at 2.7s,	estimator rf's best error=0.8443,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:26:25] {2219} INFO - iteration 33, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:25] {2392} INFO -  at 2.9s,	estimator extra_tree's best error=0.8526,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:26:25] {2219} INFO - iteration 34, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:25] {2392} INFO -  at 3.0s,	estimator lgbm's best error=0.7818,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:26:25] {2219} INFO - iteration 35, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:25] {2392} INFO -  at 3.1s,	estimator xgboost's best error=0.7887,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:26:25] {2219} INFO - iteration 36, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:26] {2392} INFO -  at 3.2s,	estimator extra_tree's best error=0.8526,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:26:26] {2219} INFO - iteration 37, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:26] {2392} INFO -  at 3.2s,	estimator xgboost's best error=0.7887,	best estimator lgbm's best error=0.7818
# [flaml.automl.logger: 07-31 17:26:26] {2219} INFO - iteration 38, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:26] {2392} INFO -  at 3.3s,	estimator xgboost's best error=0.7641,	best estimator xgboost's best error=0.7641
# [flaml.automl.logger: 07-31 17:26:26] {2219} INFO - iteration 39, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:26] {2392} INFO -  at 3.3s,	estimator xgboost's best error=0.7641,	best estimator xgboost's best error=0.7641
# [flaml.automl.logger: 07-31 17:26:26] {2219} INFO - iteration 40, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:26] {2392} INFO -  at 3.4s,	estimator xgboost's best error=0.7641,	best estimator xgboost's best error=0.7641
# [flaml.automl.logger: 07-31 17:26:26] {2219} INFO - iteration 41, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:26] {2392} INFO -  at 3.6s,	estimator extra_tree's best error=0.8481,	best estimator xgboost's best error=0.7641
# [flaml.automl.logger: 07-31 17:26:26] {2219} INFO - iteration 42, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:26] {2392} INFO -  at 3.7s,	estimator lgbm's best error=0.7818,	best estimator xgboost's best error=0.7641
# [flaml.automl.logger: 07-31 17:26:26] {2219} INFO - iteration 43, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:26] {2392} INFO -  at 3.7s,	estimator xgboost's best error=0.7641,	best estimator xgboost's best error=0.7641
# [flaml.automl.logger: 07-31 17:26:26] {2219} INFO - iteration 44, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:26] {2392} INFO -  at 3.8s,	estimator extra_tree's best error=0.8481,	best estimator xgboost's best error=0.7641
# [flaml.automl.logger: 07-31 17:26:26] {2219} INFO - iteration 45, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:26] {2392} INFO -  at 3.9s,	estimator xgboost's best error=0.7641,	best estimator xgboost's best error=0.7641
# [flaml.automl.logger: 07-31 17:26:26] {2219} INFO - iteration 46, current learner rf
# [flaml.automl.logger: 07-31 17:26:26] {2392} INFO -  at 4.1s,	estimator rf's best error=0.8443,	best estimator xgboost's best error=0.7641
# [flaml.automl.logger: 07-31 17:26:26] {2219} INFO - iteration 47, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:27] {2392} INFO -  at 4.2s,	estimator extra_tree's best error=0.8481,	best estimator xgboost's best error=0.7641
# [flaml.automl.logger: 07-31 17:26:27] {2219} INFO - iteration 48, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:27] {2392} INFO -  at 4.3s,	estimator lgbm's best error=0.7818,	best estimator xgboost's best error=0.7641
# [flaml.automl.logger: 07-31 17:26:27] {2219} INFO - iteration 49, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:27] {2392} INFO -  at 4.4s,	estimator xgboost's best error=0.7641,	best estimator xgboost's best error=0.7641
# [flaml.automl.logger: 07-31 17:26:27] {2219} INFO - iteration 50, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:27] {2392} INFO -  at 4.6s,	estimator extra_tree's best error=0.8480,	best estimator xgboost's best error=0.7641
# [flaml.automl.logger: 07-31 17:26:27] {2219} INFO - iteration 51, current learner rf
# [flaml.automl.logger: 07-31 17:26:27] {2392} INFO -  at 4.7s,	estimator rf's best error=0.8443,	best estimator xgboost's best error=0.7641
# [flaml.automl.logger: 07-31 17:26:27] {2219} INFO - iteration 52, current learner rf
# [flaml.automl.logger: 07-31 17:26:27] {2392} INFO -  at 4.9s,	estimator rf's best error=0.8271,	best estimator xgboost's best error=0.7641
# [flaml.automl.logger: 07-31 17:26:27] {2219} INFO - iteration 53, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:27] {2392} INFO -  at 5.0s,	estimator lgbm's best error=0.7798,	best estimator xgboost's best error=0.7641
# [flaml.automl.logger: 07-31 17:26:27] {2219} INFO - iteration 54, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:28] {2392} INFO -  at 5.3s,	estimator lgbm's best error=0.7798,	best estimator xgboost's best error=0.7641
# [flaml.automl.logger: 07-31 17:26:28] {2219} INFO - iteration 55, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:28] {2392} INFO -  at 5.4s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:28] {2219} INFO - iteration 56, current learner rf
# [flaml.automl.logger: 07-31 17:26:28] {2392} INFO -  at 5.5s,	estimator rf's best error=0.8271,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:28] {2219} INFO - iteration 57, current learner rf
# [flaml.automl.logger: 07-31 17:26:28] {2392} INFO -  at 5.8s,	estimator rf's best error=0.8255,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:28] {2219} INFO - iteration 58, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:28] {2392} INFO -  at 5.9s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:28] {2219} INFO - iteration 59, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:28] {2392} INFO -  at 6.0s,	estimator lgbm's best error=0.7798,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:28] {2219} INFO - iteration 60, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:29] {2392} INFO -  at 6.8s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:29] {2219} INFO - iteration 61, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:30] {2392} INFO -  at 7.1s,	estimator lgbm's best error=0.7798,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:30] {2219} INFO - iteration 62, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:30] {2392} INFO -  at 7.2s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:30] {2219} INFO - iteration 63, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:30] {2392} INFO -  at 7.3s,	estimator extra_tree's best error=0.8480,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:30] {2219} INFO - iteration 64, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:30] {2392} INFO -  at 7.4s,	estimator lgbm's best error=0.7797,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:30] {2219} INFO - iteration 65, current learner rf
# [flaml.automl.logger: 07-31 17:26:30] {2392} INFO -  at 7.6s,	estimator rf's best error=0.8255,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:30] {2219} INFO - iteration 66, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:30] {2392} INFO -  at 7.8s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:30] {2219} INFO - iteration 67, current learner rf
# [flaml.automl.logger: 07-31 17:26:31] {2392} INFO -  at 8.3s,	estimator rf's best error=0.8138,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:31] {2219} INFO - iteration 68, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:31] {2392} INFO -  at 8.3s,	estimator lgbm's best error=0.7797,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:31] {2219} INFO - iteration 69, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:31] {2392} INFO -  at 8.4s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:31] {2219} INFO - iteration 70, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:31] {2392} INFO -  at 8.9s,	estimator extra_tree's best error=0.8425,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:31] {2219} INFO - iteration 71, current learner rf
# [flaml.automl.logger: 07-31 17:26:32] {2392} INFO -  at 9.2s,	estimator rf's best error=0.8138,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:32] {2219} INFO - iteration 72, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:32] {2392} INFO -  at 9.5s,	estimator extra_tree's best error=0.8425,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:32] {2219} INFO - iteration 73, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:32] {2392} INFO -  at 9.7s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:32] {2219} INFO - iteration 74, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:33] {2392} INFO -  at 10.4s,	estimator extra_tree's best error=0.8425,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:33] {2219} INFO - iteration 75, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:33] {2392} INFO -  at 10.6s,	estimator lgbm's best error=0.7797,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:33] {2219} INFO - iteration 76, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:33] {2392} INFO -  at 10.7s,	estimator lgbm's best error=0.7693,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:33] {2219} INFO - iteration 77, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:33] {2392} INFO -  at 10.7s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:33] {2219} INFO - iteration 78, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:33] {2392} INFO -  at 10.9s,	estimator lgbm's best error=0.7657,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:33] {2219} INFO - iteration 79, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:33] {2392} INFO -  at 11.0s,	estimator lgbm's best error=0.7657,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:33] {2219} INFO - iteration 80, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:34] {2392} INFO -  at 11.2s,	estimator extra_tree's best error=0.8425,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:34] {2219} INFO - iteration 81, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:34] {2392} INFO -  at 11.4s,	estimator lgbm's best error=0.7657,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:34] {2219} INFO - iteration 82, current learner rf
# [flaml.automl.logger: 07-31 17:26:35] {2392} INFO -  at 12.5s,	estimator rf's best error=0.8048,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:35] {2219} INFO - iteration 83, current learner rf
# [flaml.automl.logger: 07-31 17:26:35] {2392} INFO -  at 13.0s,	estimator rf's best error=0.8048,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:35] {2219} INFO - iteration 84, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:36] {2392} INFO -  at 13.8s,	estimator extra_tree's best error=0.8425,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:36] {2219} INFO - iteration 85, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:36] {2392} INFO -  at 14.0s,	estimator lgbm's best error=0.7657,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:36] {2219} INFO - iteration 86, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:37] {2392} INFO -  at 14.5s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:37] {2219} INFO - iteration 87, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:37] {2392} INFO -  at 14.6s,	estimator lgbm's best error=0.7651,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:37] {2219} INFO - iteration 88, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:37] {2392} INFO -  at 14.9s,	estimator lgbm's best error=0.7651,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:37] {2219} INFO - iteration 89, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:38] {2392} INFO -  at 15.7s,	estimator extra_tree's best error=0.8349,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:38] {2219} INFO - iteration 90, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:38] {2392} INFO -  at 15.8s,	estimator lgbm's best error=0.7651,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:38] {2219} INFO - iteration 91, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:39] {2392} INFO -  at 16.1s,	estimator extra_tree's best error=0.8349,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:39] {2219} INFO - iteration 92, current learner rf
# [flaml.automl.logger: 07-31 17:26:41] {2392} INFO -  at 18.2s,	estimator rf's best error=0.8048,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:41] {2219} INFO - iteration 93, current learner rf
# [flaml.automl.logger: 07-31 17:26:42] {2392} INFO -  at 20.1s,	estimator rf's best error=0.8024,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:42] {2219} INFO - iteration 94, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:43] {2392} INFO -  at 20.2s,	estimator lgbm's best error=0.7651,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:43] {2219} INFO - iteration 95, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:44] {2392} INFO -  at 21.5s,	estimator extra_tree's best error=0.8349,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:44] {2219} INFO - iteration 96, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:44] {2392} INFO -  at 21.8s,	estimator lgbm's best error=0.7651,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:44] {2219} INFO - iteration 97, current learner rf
# [flaml.automl.logger: 07-31 17:26:45] {2392} INFO -  at 22.8s,	estimator rf's best error=0.8024,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:45] {2219} INFO - iteration 98, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:45] {2392} INFO -  at 22.9s,	estimator lgbm's best error=0.7651,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:45] {2219} INFO - iteration 99, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:45] {2392} INFO -  at 23.0s,	estimator lgbm's best error=0.7578,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:45] {2219} INFO - iteration 100, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:46] {2392} INFO -  at 23.5s,	estimator extra_tree's best error=0.8258,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:46] {2219} INFO - iteration 101, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:46] {2392} INFO -  at 23.9s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:46] {2219} INFO - iteration 102, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:47] {2392} INFO -  at 24.2s,	estimator lgbm's best error=0.7578,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:47] {2219} INFO - iteration 103, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:47] {2392} INFO -  at 24.8s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:47] {2219} INFO - iteration 104, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:48] {2392} INFO -  at 25.1s,	estimator lgbm's best error=0.7578,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:48] {2219} INFO - iteration 105, current learner rf
# [flaml.automl.logger: 07-31 17:26:52] {2392} INFO -  at 29.4s,	estimator rf's best error=0.8024,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:52] {2219} INFO - iteration 106, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:52] {2392} INFO -  at 29.7s,	estimator extra_tree's best error=0.8258,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:52] {2219} INFO - iteration 107, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:53] {2392} INFO -  at 30.5s,	estimator lgbm's best error=0.7578,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:53] {2219} INFO - iteration 108, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:54] {2392} INFO -  at 31.2s,	estimator extra_tree's best error=0.8258,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:54] {2219} INFO - iteration 109, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:54] {2392} INFO -  at 31.3s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:54] {2219} INFO - iteration 110, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:54] {2392} INFO -  at 31.4s,	estimator lgbm's best error=0.7578,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:54] {2219} INFO - iteration 111, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:54] {2392} INFO -  at 32.0s,	estimator extra_tree's best error=0.8258,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:54] {2219} INFO - iteration 112, current learner xgboost
# [flaml.automl.logger: 07-31 17:26:55] {2392} INFO -  at 32.3s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:55] {2219} INFO - iteration 113, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:55] {2392} INFO -  at 32.7s,	estimator extra_tree's best error=0.8136,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:55] {2219} INFO - iteration 114, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:55] {2392} INFO -  at 33.0s,	estimator lgbm's best error=0.7578,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:55] {2219} INFO - iteration 115, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:56] {2392} INFO -  at 33.1s,	estimator lgbm's best error=0.7578,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:56] {2219} INFO - iteration 116, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:56] {2392} INFO -  at 33.8s,	estimator extra_tree's best error=0.8136,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:56] {2219} INFO - iteration 117, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:56] {2392} INFO -  at 34.1s,	estimator extra_tree's best error=0.8136,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:56] {2219} INFO - iteration 118, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:57] {2392} INFO -  at 34.5s,	estimator lgbm's best error=0.7578,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:57] {2219} INFO - iteration 119, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:57] {2392} INFO -  at 34.8s,	estimator extra_tree's best error=0.8136,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:57] {2219} INFO - iteration 120, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:58] {2392} INFO -  at 35.2s,	estimator extra_tree's best error=0.8136,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:58] {2219} INFO - iteration 121, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:58] {2392} INFO -  at 35.6s,	estimator extra_tree's best error=0.8136,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:58] {2219} INFO - iteration 122, current learner extra_tree
# [flaml.automl.logger: 07-31 17:26:59] {2392} INFO -  at 36.2s,	estimator extra_tree's best error=0.8078,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:59] {2219} INFO - iteration 123, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:26:59] {2392} INFO -  at 36.3s,	estimator xgb_limitdepth's best error=0.8130,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:59] {2219} INFO - iteration 124, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:26:59] {2392} INFO -  at 36.3s,	estimator xgb_limitdepth's best error=0.8130,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:59] {2219} INFO - iteration 125, current learner lgbm
# [flaml.automl.logger: 07-31 17:26:59] {2392} INFO -  at 36.5s,	estimator lgbm's best error=0.7578,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:26:59] {2219} INFO - iteration 126, current learner rf
# [flaml.automl.logger: 07-31 17:27:00] {2392} INFO -  at 37.5s,	estimator rf's best error=0.8024,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:00] {2219} INFO - iteration 127, current learner rf
# [flaml.automl.logger: 07-31 17:27:01] {2392} INFO -  at 38.5s,	estimator rf's best error=0.8024,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:01] {2219} INFO - iteration 128, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:27:01] {2392} INFO -  at 38.6s,	estimator xgb_limitdepth's best error=0.8130,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:01] {2219} INFO - iteration 129, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:27:01] {2392} INFO -  at 38.6s,	estimator xgb_limitdepth's best error=0.8130,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:01] {2219} INFO - iteration 130, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:27:01] {2392} INFO -  at 38.7s,	estimator xgb_limitdepth's best error=0.8130,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:01] {2219} INFO - iteration 131, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:27:01] {2392} INFO -  at 38.7s,	estimator xgb_limitdepth's best error=0.8130,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:01] {2219} INFO - iteration 132, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:27:01] {2392} INFO -  at 38.8s,	estimator xgb_limitdepth's best error=0.8130,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:01] {2219} INFO - iteration 133, current learner xgboost
# [flaml.automl.logger: 07-31 17:27:01] {2392} INFO -  at 39.0s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:01] {2219} INFO - iteration 134, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:27:01] {2392} INFO -  at 39.1s,	estimator xgb_limitdepth's best error=0.8130,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:01] {2219} INFO - iteration 135, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:27:02] {2392} INFO -  at 39.1s,	estimator xgb_limitdepth's best error=0.8130,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:02] {2219} INFO - iteration 136, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:27:02] {2392} INFO -  at 39.1s,	estimator xgb_limitdepth's best error=0.8023,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:02] {2219} INFO - iteration 137, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:27:02] {2392} INFO -  at 39.2s,	estimator xgb_limitdepth's best error=0.7963,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:02] {2219} INFO - iteration 138, current learner rf
# [flaml.automl.logger: 07-31 17:27:05] {2392} INFO -  at 42.8s,	estimator rf's best error=0.7997,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:05] {2219} INFO - iteration 139, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:27:05] {2392} INFO -  at 42.9s,	estimator xgb_limitdepth's best error=0.7963,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:05] {2219} INFO - iteration 140, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:27:05] {2392} INFO -  at 42.9s,	estimator xgb_limitdepth's best error=0.7963,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:05] {2219} INFO - iteration 141, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:27:05] {2392} INFO -  at 43.0s,	estimator xgb_limitdepth's best error=0.7963,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:05] {2219} INFO - iteration 142, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:27:05] {2392} INFO -  at 43.1s,	estimator xgb_limitdepth's best error=0.7963,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:05] {2219} INFO - iteration 143, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:27:06] {2392} INFO -  at 43.1s,	estimator xgb_limitdepth's best error=0.7963,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:06] {2219} INFO - iteration 144, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:27:06] {2392} INFO -  at 43.3s,	estimator xgb_limitdepth's best error=0.7963,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:06] {2219} INFO - iteration 145, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:27:06] {2392} INFO -  at 43.4s,	estimator xgb_limitdepth's best error=0.7963,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:06] {2219} INFO - iteration 146, current learner rf
# [flaml.automl.logger: 07-31 17:27:11] {2392} INFO -  at 48.3s,	estimator rf's best error=0.7997,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:11] {2219} INFO - iteration 147, current learner lgbm
# [flaml.automl.logger: 07-31 17:27:11] {2392} INFO -  at 48.4s,	estimator lgbm's best error=0.7578,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:11] {2219} INFO - iteration 148, current learner lgbm
# [flaml.automl.logger: 07-31 17:27:11] {2392} INFO -  at 49.0s,	estimator lgbm's best error=0.7576,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:11] {2219} INFO - iteration 149, current learner lgbm
# [flaml.automl.logger: 07-31 17:27:13] {2392} INFO -  at 50.5s,	estimator lgbm's best error=0.7576,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:13] {2219} INFO - iteration 150, current learner rf
# [flaml.automl.logger: 07-31 17:27:16] {2392} INFO -  at 53.7s,	estimator rf's best error=0.7976,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:16] {2219} INFO - iteration 151, current learner xgboost
# [flaml.automl.logger: 07-31 17:27:16] {2392} INFO -  at 53.8s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:16] {2219} INFO - iteration 152, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:27:16] {2392} INFO -  at 53.9s,	estimator xgb_limitdepth's best error=0.7963,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:16] {2219} INFO - iteration 153, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:27:17] {2392} INFO -  at 54.1s,	estimator xgb_limitdepth's best error=0.7963,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:17] {2219} INFO - iteration 154, current learner lgbm
# [flaml.automl.logger: 07-31 17:27:17] {2392} INFO -  at 54.5s,	estimator lgbm's best error=0.7576,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:17] {2219} INFO - iteration 155, current learner lgbm
# [flaml.automl.logger: 07-31 17:27:17] {2392} INFO -  at 54.7s,	estimator lgbm's best error=0.7576,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:17] {2219} INFO - iteration 156, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:27:17] {2392} INFO -  at 54.8s,	estimator xgb_limitdepth's best error=0.7876,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:17] {2219} INFO - iteration 157, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:27:17] {2392} INFO -  at 54.8s,	estimator xgb_limitdepth's best error=0.7876,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:17] {2219} INFO - iteration 158, current learner xgboost
# [flaml.automl.logger: 07-31 17:27:17] {2392} INFO -  at 55.0s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:17] {2219} INFO - iteration 159, current learner xgboost
# [flaml.automl.logger: 07-31 17:27:18] {2392} INFO -  at 55.1s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:18] {2219} INFO - iteration 160, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:27:18] {2392} INFO -  at 55.2s,	estimator xgb_limitdepth's best error=0.7876,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:18] {2219} INFO - iteration 161, current learner rf
# [flaml.automl.logger: 07-31 17:27:18] {2392} INFO -  at 55.7s,	estimator rf's best error=0.7976,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:18] {2219} INFO - iteration 162, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:27:18] {2392} INFO -  at 55.8s,	estimator xgb_limitdepth's best error=0.7876,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:18] {2219} INFO - iteration 163, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:27:18] {2392} INFO -  at 55.9s,	estimator xgb_limitdepth's best error=0.7876,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:18] {2219} INFO - iteration 164, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:27:18] {2392} INFO -  at 56.0s,	estimator xgb_limitdepth's best error=0.7876,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:18] {2219} INFO - iteration 165, current learner xgboost
# [flaml.automl.logger: 07-31 17:27:19] {2392} INFO -  at 56.3s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:19] {2219} INFO - iteration 166, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:27:19] {2392} INFO -  at 56.6s,	estimator xgb_limitdepth's best error=0.7874,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:19] {2219} INFO - iteration 167, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:27:19] {2392} INFO -  at 56.9s,	estimator xgb_limitdepth's best error=0.7874,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:19] {2219} INFO - iteration 168, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:27:20] {2392} INFO -  at 57.1s,	estimator xgb_limitdepth's best error=0.7874,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:20] {2219} INFO - iteration 169, current learner xgboost
# [flaml.automl.logger: 07-31 17:27:20] {2392} INFO -  at 57.2s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:20] {2219} INFO - iteration 170, current learner lgbm
# [flaml.automl.logger: 07-31 17:27:21] {2392} INFO -  at 58.5s,	estimator lgbm's best error=0.7576,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:21] {2219} INFO - iteration 171, current learner lgbm
# [flaml.automl.logger: 07-31 17:27:21] {2392} INFO -  at 58.6s,	estimator lgbm's best error=0.7576,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:21] {2219} INFO - iteration 172, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:27:21] {2392} INFO -  at 58.7s,	estimator xgb_limitdepth's best error=0.7874,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:21] {2219} INFO - iteration 173, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:27:22] {2392} INFO -  at 59.5s,	estimator xgb_limitdepth's best error=0.7874,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:22] {2219} INFO - iteration 174, current learner xgb_limitdepth
# [flaml.automl.logger: 07-31 17:27:22] {2392} INFO -  at 59.8s,	estimator xgb_limitdepth's best error=0.7796,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:22] {2219} INFO - iteration 175, current learner xgboost
# [flaml.automl.logger: 07-31 17:27:22] {2392} INFO -  at 60.0s,	estimator xgboost's best error=0.7564,	best estimator xgboost's best error=0.7564
# [flaml.automl.logger: 07-31 17:27:22] {2526} INFO - [('xgboost', {'n_jobs': -1, 'n_estimators': 46, 'max_leaves': 10, 'min_child_weight': 31.313971131799327, 'learning_rate': 0.16419452319617214, 'subsample': 0.8895588746662894, 'colsample_bylevel': 0.7451482071279635, 'colsample_bytree': 0.7699341827365839, 'reg_alpha': 0.0015245843735931766, 'reg_lambda': 0.015166903330162405, 'max_depth': 0, 'grow_policy': 'lossguide', 'tree_method': 'hist', 'verbosity': 0}), ('lgbm', {'n_jobs': -1, 'n_estimators': 284, 'num_leaves': 5, 'min_child_samples': 34, 'learning_rate': 0.13105833877219852, 'colsample_bytree': 0.7436978573884088, 'reg_alpha': 0.4462319631027731, 'reg_lambda': 0.0009765625, 'max_bin': 255, 'verbose': -1}), ('xgb_limitdepth', {'n_jobs': -1, 'n_estimators': 41, 'max_depth': 11, 'min_child_weight': 4.339981832670022, 'learning_rate': 0.10226456595078688, 'subsample': 1.0, 'colsample_bylevel': 0.8415426072447759, 'colsample_bytree': 0.9505186456050482, 'reg_alpha': 0.0009765625, 'reg_lambda': 19.179103086299612, 'verbosity': 0}), ('rf', {'n_jobs': -1, 'n_estimators': 853, 'max_features': 0.371874280579337, 'max_leaf_nodes': 101, 'random_state': 12032022, 'verbose': 0}), ('extra_tree', {'n_jobs': -1, 'n_estimators': 200, 'max_features': 0.3611279687956865, 'max_leaf_nodes': 125, 'random_state': 12032022, 'verbose': 0})]
# [flaml.automl.logger: 07-31 17:27:22] {2569} INFO - Building ensemble with tuned estimators
# [flaml.automl.logger: 07-31 17:27:33] {2575} INFO - ensemble: StackingRegressor(estimators=[('xgboost',
#                                <flaml.automl.model.XGBoostSklearnEstimator object at 0x3046c2250>),
#                               ('lgbm',
#                                <flaml.automl.model.LGBMEstimator object at 0x3046c4e80>),
#                               ('xgb_limitdepth',
#                                <flaml.automl.model.XGBoostLimitDepthEstimator object at 0x30460c220>),
#                               ('rf',
#                                <flaml.automl.model.RandomForestEstimator object at 0x304765e50>),
#                               ('extra_tree',
#                                <flaml.automl.model.ExtraTreesEstimator object at 0x3047656d0>)],
#                   final_estimator=RLasso(), n_jobs=1)
# [flaml.automl.logger: 07-31 17:27:33] {1931} INFO - fit succeeded
# [flaml.automl.logger: 07-31 17:27:33] {1932} INFO - Time taken to find the best model: 5.369256973266602
# Pipeline(steps=[('formulatransformer',
#                  FormulaTransformer(formula='0 + female + age + race + '
#                                             'children + marital + education + '
#                                             'RN_experience + RN_experience**2 '
#                                             '+ RN_experience**3 + '
#                                             'RN_experience**4 + left_nursing + '
#                                             'country_ed_US + english_only + '
#                                             'military + certificates+ '
#                                             'labor_union + work_setting + '
#                                             'work_situation + level_care + '
#                                             'care_specialty + state')),
#                 ('automl',
#                  AutoML(ap...
#                         keep_search_state=False, learner_selector='sample',
#                         log_file_name='', log_training_metric=False,
#                         log_type='better', max_iter=None, mem_thres=4294967296,
#                         metric='r2', metric_constraints=[],
#                         min_sample_size=10000, mlflow_logging=True,
#                         model_history=False, n_concurrent_trials=1, n_jobs=-1,
#                         n_splits=3, pred_time_limit=inf,
#                         preserve_checkpoint=True, retrain_full=True, ...))])

# %%
# Out-of-sample performance
mse, semse, r2 = metrics(Z.iloc[test_idx], y[test_idx], automl)
# Out:
# 0.0084, 0.0007, 0.2555
